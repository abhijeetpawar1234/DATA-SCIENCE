# %%
conda install pandas
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.3.2
#     latest version: 26.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/miniconda3/envs/ds
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-3.0.5               |  py311h3f644e9_0        13.6 MB
#     python-dateutil-2.9.0post0 |  py311hca03da5_2         325 KB
#     six-1.17.0                 |  py311hca03da5_0          39 KB
#     ------------------------------------------------------------
#                                            Total:        13.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             pkgs/main/osx-arm64::pandas-3.0.5-py311h3f644e9_0
#   python-dateutil    pkgs/main/osx-arm64::python-dateutil-2.9.0post0-py311hca03da5_2
#   six                pkgs/main/osx-arm64::six-1.17.0-py311hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# pandas-3.0.5         | 13.6 MB   |                                       |   0%
# python-dateutil-2.9. | 325 KB    |                                       |   0%
#
# six-1.17.0           | 39 KB     |                                       |   0%
#
# six-1.17.0           | 39 KB     | ###############1                      |  41%
# python-dateutil-2.9. | 325 KB    | #8                                    |   5%
#
# six-1.17.0           | 39 KB     | ##################################### | 100%
#
# pandas-3.0.5         | 13.6 MB   |                                       |   0%
# python-dateutil-2.9. | 325 KB    | ####################                  |  54%
# python-dateutil-2.9. | 325 KB    | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s = pd.Series([122,22,32,42,67])
type(s)
# Out:
# pandas.Series

# %%
print(s)
# Out:
# 0    122
# 1     22
# 2     32
# 3     42
# 4     67
# dtype: int64

# %% [markdown]
# Pandas is built on two main data structures:
#
# Series → One-dimensional (like a single column in Excel)
# DataFrame → Two-dimensional (like a full spreadsheet or SQL table)

# %%
s1 = pd.Series([122,22,32,42,67] , index = ['abhi','joe','ajay','bob','cameron'])
print(s1)
# Out:
# abhi       122
# joe         22
# ajay        32
# bob         42
# cameron     67
# dtype: int64

# %%
s1['abhi']
# Out:
# np.int64(122)

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index         # Row labels
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns       # Column labels
# Out:
# Index(['name', 'age', 'city'], dtype='str')
