# %% [raw]
# Once your data is clean, the next step is to reshape, reformat, and reorder it as needed for analysis. Pandas gives you plenty of flexible tools to do this.

# %% [markdown]
# # Sorting & Ranking

# %%
import pandas as pd
df = pd.read_csv("Newdata.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# # Sort by Values

# %%
df2 = df.sort_values('Year').copy()  # Ascending sort

# %%
df2 = df.sort_values(['Year','IMDb']).copy()  # Sort by multiple columns

# %% [markdown]
# Reset Index:
# If you want the index to start from 0 and be sequential, you can reset it using reset_index()

# %%
df2.reset_index(drop=True,inplace=True)  # Reset the index and drop the old index

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   2024   8.4
# 1                    565   6.0
# 2                    201   6.1
# 3                    585   7.0
# 4                    180   7.5
# 5                    111   8.3
# 6                    475   6.5
# 7                    318   7.0
# 8                    342   8.2
# 9                    431   5.6
# 10                   266   5.9
# 11                  1050   7.2

# %%
df.sort_values('Year', ascending=False) # Descending sort
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 9                    266   5.9
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 1                    565   6.0
# 10                   201   6.1
# 2                   2024   8.4

# %% [markdown]
# Sort by Index

# %%
df2.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   2024   8.4
# 1                    565   6.0
# 2                    201   6.1
# 3                    585   7.0
# 4                    180   7.5
# 5                    111   8.3
# 6                    475   6.5
# 7                    318   7.0
# 8                    342   8.2
# 9                    431   5.6
# 10                   266   5.9
# 11                  1050   7.2

# %% [markdown]
# # Ranking
# The .rank() function in pandas is used to assign ranks to numeric values in a column, like scores or points. By default, it gives the average rank to tied values, which can result in decimal numbers. For example, if two people share the top score, they both get a rank of 1.5. You can customize the ranking behavior using the method parameter. One useful option is method='dense', which assigns the same rank to ties but doesn’t leave gaps in the ranking sequence. This is helpful when you want a clean, consecutive ranking system without skips.

# %%
#df2["Rank"] = df2["IMDb"].rank()                 # Default: average method
df2["Rank"] = df2["IMDb"].rank(method="dense",ascending=False)   # # 1, 2, 2, 3

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   2024   8.4   1.0
# 1                    565   6.0   9.0
# 2                    201   6.1   8.0
# 3                    585   7.0   6.0
# 4                    180   7.5   4.0
# 5                    111   8.3   2.0
# 6                    475   6.5   7.0
# 7                    318   7.0   6.0
# 8                    342   8.2   3.0
# 9                    431   5.6  11.0
# 10                   266   5.9  10.0
# 11                  1050   7.2   5.0

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# # Renaming Columns & Index

# %%
df.rename(columns={"Actor": "Hero"}, inplace=True)

# %%
df
# Out:
#                   Hero                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %%
df.rename(index={0: "row1", 1: "row2"}, inplace=True)

# %%
df
# Out:
#                     Hero                      Film  Year            Genre  \
# row1      Shah Rukh Khan                   Pathaan  2023           Action
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6          Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#       BoxOffice(INR Crore)  IMDb
# row1                  1050   7.2
# row2                   565   6.0
# 2                     2024   8.4
# 3                      431   5.6
# 4                      585   7.0
# 5                      111   8.3
# 6                      180   7.5
# 7                      475   6.5
# 8                      318   7.0
# 9                      266   5.9
# 10                     201   6.1
# 11                     342   8.2

# %% [markdown]
# To rename all columns:

# %%
df.columns = ["Name", "picture", "sal","Type","paisa","rating"]

# %%
df
# Out:
#                     Name                   picture   sal             Type  \
# row1      Shah Rukh Khan                   Pathaan  2023           Action
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6          Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#       paisa  rating
# row1   1050     7.2
# row2    565     6.0
# 2      2024     8.4
# 3       431     5.6
# 4       585     7.0
# 5       111     8.3
# 6       180     7.5
# 7       475     6.5
# 8       318     7.0
# 9       266     5.9
# 10      201     6.1
# 11      342     8.2

# %% [markdown]
# # Changing Column Order
# Just pass a new list of column names:

# %%
df = df[["picture", "Name", "rating","sal","Type","paisa"]]   # Reorder as desired

# %%
df
# Out:
#                        picture                Name  rating   sal  \
# row1                   Pathaan      Shah Rukh Khan     7.2  2023
# row2           Tiger Zinda Hai         Salman Khan     6.0  2017
# 2                       Dangal          Aamir Khan     8.4  2016
# 3                   Brahmastra       Ranbir Kapoor     5.6  2022
# 4                    Padmaavat       Ranveer Singh     7.0  2018
# 5                    Andhadhun  Ayushmann Khurrana     8.3  2018
# 6                        Stree       Rajkummar Rao     7.5  2018
# 7                          War      Hrithik Roshan     6.5  2019
# 8                   Good Newwz        Akshay Kumar     7.0  2019
# 9            Bhool Bhulaiyaa 2       Kartik Aaryan     5.9  2022
# 10       Badrinath Ki Dulhania        Varun Dhawan     6.1  2017
# 11    Uri: The Surgical Strike       Vicky Kaushal     8.2  2019
#
#                  Type  paisa
# row1           Action   1050
# row2           Action    565
# 2           Biography   2024
# 3             Fantasy    431
# 4          Historical    585
# 5            Thriller    111
# 6       Horror Comedy    180
# 7              Action    475
# 8              Comedy    318
# 9       Horror Comedy    266
# 10    Romantic Comedy    201
# 11             Action    342

# %% [raw]
# You can also move one column to the front:

# %%
cols = ["Name"] + [col for col in df.columns if col != "Name"]
df = df[cols]

# %%
df
# Out:
#                     Name                   picture  rating   sal  \
# row1      Shah Rukh Khan                   Pathaan     7.2  2023
# row2         Salman Khan           Tiger Zinda Hai     6.0  2017
# 2             Aamir Khan                    Dangal     8.4  2016
# 3          Ranbir Kapoor                Brahmastra     5.6  2022
# 4          Ranveer Singh                 Padmaavat     7.0  2018
# 5     Ayushmann Khurrana                 Andhadhun     8.3  2018
# 6          Rajkummar Rao                     Stree     7.5  2018
# 7         Hrithik Roshan                       War     6.5  2019
# 8           Akshay Kumar                Good Newwz     7.0  2019
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2     5.9  2022
# 10          Varun Dhawan     Badrinath Ki Dulhania     6.1  2017
# 11         Vicky Kaushal  Uri: The Surgical Strike     8.2  2019
#
#                  Type  paisa
# row1           Action   1050
# row2           Action    565
# 2           Biography   2024
# 3             Fantasy    431
# 4          Historical    585
# 5            Thriller    111
# 6       Horror Comedy    180
# 7              Action    475
# 8              Comedy    318
# 9       Horror Comedy    266
# 10    Romantic Comedy    201
# 11             Action    342
