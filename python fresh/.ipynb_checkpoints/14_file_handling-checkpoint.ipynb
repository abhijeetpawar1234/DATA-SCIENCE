# %%
f = open("text.txt","r")
f.read()
# Out:
# 'abhi\nis programmer'

# %%
s = 'this is data science learning'
f1 = open('abc.txt', "w")
f1.write(s)
# Out:
# 29

# %%
f1.close()

# %%
f.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 os.remove('abc.txt')
#
# NameError: name 'os' is not defined
