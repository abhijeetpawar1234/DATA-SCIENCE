# %%
name = "abhi"
name
# Out:
# 'abhi'

# %%
name.upper()
# Out:
# 'ABHI'

# %%
name.endswith('hi')
# Out:
# True

# %%
name.endswith('jey')
# Out:
# False

# %%
name.lower()
# Out:
# 'abhi'

# %%
name.count('r')
# Out:
# 0

# %%
len("Hello")
# Out:
# 5
