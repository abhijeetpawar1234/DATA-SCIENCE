# %% [markdown]
# arithmetic operatoe

# %%
a = 10 
b = 6

# %%
a + b
# Out:
# 16

# %%
a - b
# Out:
# 4

# %%
a * b
# Out:
# 60

# %%
a / b
# Out:
# 1.6666666666666667

# %%
a // b
# Out:
# 1

# %%
2**2
# Out:
# 4

# %%
a%b
# Out:
# 4

# %% [markdown]
# comparision operator

# %%
a = 45
b = 4

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
c = 3
a == c #is a equal to c
# Out:
# False

# %%
a != c # a not equal to c
# Out:
# True

# %%
a = 5
b = 5

# %%
a == b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
b1  = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
 b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a = 45

# %%
a += 4

# %%
print(a)
# Out:
# 49
