# %%
a = input("enter the value of a") # by default it take as string
# Out:
# enter the value of a 1

# %%
a
# Out:
# '1'

# %%
b = input("enter value of b")
# Out:
# enter value of b 23

# %%
print(a+b)
# Out:
# 123

# %%
int(a)+int(b)
# Out:
# 24

# %%
c = input()
# Out:
#  1

# %%
c
# Out:
# '1'
