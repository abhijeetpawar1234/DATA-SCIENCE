# %%
a = 400

# %%
if(a>45):
    print("greater")
else:
    print('smaller')
# Out:
# greater

# %%
x = 5
if x > 10:
    print("x is greater than 10")
elif x > 5:
    print("x is greater than 5 but not more than 10")
elif x == 5:
    print("x is exactly 5")
else:
    print("x is less than 5")
# Out:
# x is exactly 5

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Score': [85, 40, 75]}
df = pd.DataFrame(data)

df['Result'] = df['Score'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')
print(df)

# %%
def add(a , b):
    return a + b

# %%
add(10,30)
# Out:
# 40

# %%
def add(a , b=1): # default argument
    return a + b

# %%
add(10)
# Out:
# 11

# %%
def greet():
    print('hello mfs')

# %%
greet()
# Out:
# hello mfs
