# %%
code = 2000

# %%
match code:
    case 200:
        print("ok")
    case 400:
        print("bad response")
    case 500:
        print('not found')
    case _:
        print('nothing found')

print('end of program')
# Out:
# nothing found
# end of program
