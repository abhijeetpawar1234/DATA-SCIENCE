# %%
l = [1,4,55,32,1]
l[2]
# Out:
# 55

# %%
l[0]
# Out:
# 1

# %%
l[0]=6
l
# Out:
# [6, 4, 55, 32, 1]

# %%
l.append(4)

# %%
l
# Out:
# [6, 4, 55, 32, 1, 4]

# %%
l2 = [5,6]
l.extend(l2)

# %%
l
# Out:
# [6, 4, 55, 32, 1, 4, 5, 6]

# %%
l.insert(1,200) # insert  200 at index 1
l
# Out:
# [6, 200, 4, 55, 32, 1, 4, 5, 6]

# %%
l.pop(2) #  4 will be pop at index 2
l
# Out:
# [6, 200, 55, 32, 1, 4, 5, 6]

# %%
l.index(200)
# Out:
# 1

# %%
l.append(4)
l.count(4)
# Out:
# 2

# %%
l.sort()
l
# Out:
# [1, 4, 4, 5, 6, 6, 32, 55, 200]

# %%
sorted(l)
# Out:
# [1, 4, 4, 5, 6, 6, 32, 55, 200]

# %%
newl = [1,3,44,22,78,0,2]
sorted(newl)
# Out:
# [0, 1, 2, 3, 22, 44, 78]

# %%
newl
# Out:
# [1, 3, 44, 22, 78, 0, 2]

# %%
y = [1,2,'hello',True,[False , 2.00]]
y
# Out:
# [1, 2, 'hello', True, [False, 2.0]]

# %%
y[4]
# Out:
# [False, 2.0]

# %%
l+y  #list conctatination
# Out:
# [1, 4, 4, 5, 6, 6, 32, 55, 200, 1, 2, 'hello', True, [False, 2.0]]

# %%
l
# Out:
# [1, 4, 4, 5, 6, 6, 32, 55, 200]

# %%
y
# Out:
# [1, 2, 'hello', True, [False, 2.0]]

# %%
if 88 in y:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
3 in l
# Out:
# False

# %%
s = "jack-deo-salman"
s.split('-')
# Out:
# ['jack', 'deo', 'salman']
