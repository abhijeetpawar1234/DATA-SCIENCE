# %%
a = {}
type(a)
# Out:
# dict

# %%
b = set()
type(b)
# Out:
# set

# %%
s = {4,2,6,8,88}

# %%
s
# Out:
# {2, 4, 6, 8, 88}

# %%
# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)  # {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {4,2,6,8,88}

# %%
s.add(34)

# %%
s
# Out:
# {2, 4, 6, 8, 34, 88}

# %%
s.update([111,112,113])
s
# Out:
# {2, 4, 6, 8, 34, 88, 111, 112, 113}

# %%
s.remove(88)
s
# Out:
# {2, 4, 6, 34, 111, 112, 113}

# %%
s.discard(1)

# %%
s
# Out:
# {2, 4, 6, 34, 88, 111, 112, 113}

# %%
s.pop()
# Out:
# 2

# %%
s1=s.copy()
s1
# Out:
# {4, 6, 34, 111, 112, 113}

# %%
s1.clear()
s1
# Out:
# set()

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
# Union – combines all unique elements
print(set1 | set2)            # {1, 2, 3, 4, 5, 6}
print(set1.union(set2))       # same result
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}

# %%
# Intersection – common elements
print(set1 & set2)            # {3, 4}
print(set1.intersection(set2))# same result
# Out:
# {3, 4}
# {3, 4}

# %%
# Difference – in set1 but not in set2
print(set1 - set2)            # {1, 2}
print(set1.difference(set2))  # same result
# Out:
# {1, 2}
# {1, 2}

# %%
sub = {1,3}
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
