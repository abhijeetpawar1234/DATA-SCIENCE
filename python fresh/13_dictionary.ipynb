# %%
d = {}
type(d)
# Out:
# dict

# %%
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}
student
# Out:
# {'name': 'Alice', 'age': 25, 'grade': 'A'}

# %%
student["grade"]
# Out:
# 'A'

# %%
r = student.get("name1")
print(r)
# Out:
# None

# %%
student['age'] = 30

# %%
print(student['age'] )
# Out:
# 30

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 30, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('grade', 'A')])

# %%
student.update({'name':'anhi','language':'null'})
student
# Out:
# {'name': 'anhi', 'age': 30, 'grade': 'A', 'language': 'null'}

# %%
student.pop("grade")
student
# Out:
# {'age': 30, 'language': 'null'}
