# %%
import json
obj = {'name':'joe' , 'age':'20'}
s =json.dumps(obj)
s
# Out:
# '{"name": "joe", "age": "20"}'

# %%
d = json.loads('{"name": "joe", "age": "20"}')

# %%
type(d)
# Out:
# dict

# %%
print(d)
# Out:
# {'name': 'joe', 'age': '20'}

# %%
file = open('data.json','w')

# %%
json.dump(obj,file)

# %%
file.close()
